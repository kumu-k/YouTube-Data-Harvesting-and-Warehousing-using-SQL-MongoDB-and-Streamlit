# %%
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
api_key = "AIzaSyAX0WBz3m3kDwHrEh25gOrPmeYWUIUlSWo"
api_service_name = 'youtube'
api_version = 'v3'
youtube=build(api_service_name, api_version, developerKey=api_key)

# %%
def Channel_id(channel_id):
    raw_data=[]
    api_key = "AIzaSyD6a-fcovIUsEx_x54oJqxR7Kp6W_E2dqw"
    api_service_name = 'youtube'
    api_version = 'v3'
    youtube=build(api_service_name, api_version, developerKey=api_key)
    get_data=youtube.channels().list(part="snippet,contentDetails,statistics",id=channel_id)
    request=get_data.execute()
    for item in request["items"]:
        data={'channelName':item["snippet"]["title"],
             'subcription':item["statistics"]["subscriberCount"],
             'views':item["statistics"]["viewCount"],
             'total_videos':item["statistics"]["videoCount"],
             'playlist_id':item["contentDetails"]["relatedPlaylists"]["uploads"]}
        raw_data.append(data)
    return(pd.DataFrame(raw_data))
cid=input("channel ID")
Channel_id(cid)
#Channel_id("UCnKhQkCUS1oCEvjuTfU4xIw")
# Out:
# channel IDUCnKhQkCUS1oCEvjuTfU4xIw
#   channelName subcription      views total_videos               playlist_id
# 0   Tech Boss     3740000  883630625         1407  UUnKhQkCUS1oCEvjuTfU4xIw

# %%
raw_data1=[]
api_key = "AIzaSyBsYY3Vysqe8dbuvalGLLECqh3960Gqahc"
api_service_name = 'youtube'
api_version = 'v3'
youtube=build(api_service_name, api_version, developerKey=api_key)
get_data=youtube.channels().list(
    part="snippet,contentDetails,statistics",
    #id ='UCnKhQkCUS1oCEvjuTfU4xIw')
    id =cid)
request=get_data.execute()

for item in request["items"]:
    data={'channel_id':item["id"],
            'channelName':item["snippet"]["title"],
             'subcription':item["statistics"]["subscriberCount"],
             'views':item["statistics"]["viewCount"],
             'total_videos':item["statistics"]["videoCount"],
             'playlist_id':item["contentDetails"]["relatedPlaylists"]["uploads"],
             'description':item["snippet"]["description"],
              'publishedAt':item["snippet"]["publishedAt"],
              'viewCount':item["statistics"]["viewCount"]}
    raw_data1.append(data)
    
pd.DataFrame(raw_data1)
# Out:
#                  channel_id channelName subcription      views total_videos  \
# 0  UCnKhQkCUS1oCEvjuTfU4xIw   Tech Boss     3740000  883630625         1407
#
#                 playlist_id  \
# 0  UUnKhQkCUS1oCEvjuTfU4xIw
#
#                                          description           publishedAt  \
# 0  Tech Boss Channel is an authentic where you ca...  2018-04-12T04:49:58Z
#
#    viewCount
# 0  883630625

# %%
playlist_id= "UUnKhQkCUS1oCEvjuTfU4xIw"
#playlist_id=cid
def Channel_vid(youtube,playlist_id):
    vid_data=[]
    get_data=youtube.playlistItems().list(part="snippet,contentDetails",
                            playlistId=playlist_id, maxResults=40)
    request=get_data.execute()
    for item in request["items"]:
        vid_data.append(item["contentDetails"]["videoId"])
    next_page=request.get("nextPageToken")
    while next_page is not None:
        get_data=youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id, 
                maxResults=40,
                pageToken = next_page)
        request=get_data.execute()
        for item in request["items"]:
            vid_data.append(item["contentDetails"]["videoId"])
        next_page=request.get("nextPageToken")
    return vid_data
vid_data = Channel_vid(youtube,playlist_id)

# %%
len(vid_data)
# Out:
# 1408

# %%
def video_info(youtube,vid_data):
    vid_info=[]
    for i in range(0, len(vid_data),40):
        get_data=youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(vid_data[i:i+40]))
        value=get_data.execute()
        for vid in value['items']:
            details={'snippet':['chennelTitle','Title','description','tags','publishedAt'],
                    'statistics':['viewCount','likeCount','favouriteCount','commentCount'],
                    'contentDetails':['duration','definition','caption']
                    }
            info={}
            info['video_id']= vid['id']
            for j in details.keys():
                for k in details[j]:
                    try:
                        info[k] = vid[j][k]
                    except:
                        info[k] = None
            vid_info.append(info)
    return pd.DataFrame(vid_info)
vid_df = video_info(youtube,vid_data)

# %%
vid_df
# Out:
#          video_id chennelTitle Title  \
# 0     Ad-xWVaohVQ         None  None
# 1     6zjB74XbDs8         None  None
# 2     4XAw4yUMWYU         None  None
# 3     6rBtYBtrhwA         None  None
# 4     M6qK-Q6pKdM         None  None
# ...           ...          ...   ...
# 1403  5jQsr0PfNCQ         None  None
# 1404  HUYng0m8DC8         None  None
# 1405  ztLI7LGJbG8         None  None
# 1406  vBqO4gCIEKk         None  None
# 1407  HRxA_kAVBFM         None  None
#
#                                             description  \
# 0     ---\nMedia Partner : Adada Creators\nEmail : t...
# 1     ---\nMedia Partner : Adada Creators\nEmail : t...
# 2     ---\nMedia Partner : Adada Creators\nEmail : t...
# 3     ---\nMedia Partner : Adada Creators\nEmail : t...
# 4     #TecnoPhantomVFold #TechBoss #Tecno \n\n---\nM...
# ...                                                 ...
# 1403  Best Buy Link : http://fkrt.it/ci4k2KNNNN\n\nஒ...
# 1404  Engineering Counsellingக்கு ஆன்லைனில் அப்பளை ச...
# 1405  Best Buy Link:\n\nBlackt Electrotech : (BT81D)...
# 1406  Buy Here:\nhttps://goo.gl/93Hesu\nhttps://goo....
# 1407  Link : https://amzn.to/2vG61ej\n\nUnboxing & R...
#
#                                                    tags           publishedAt  \
# 0                                            [Techboss]  2023-05-17T04:31:00Z
# 1                                            [Techboss]  2023-05-16T11:00:47Z
# 2                                            [Techboss]  2023-05-15T06:04:30Z
# 3                                            [Techboss]  2023-05-13T11:34:00Z
# 4     [Techboss, Tecno Phantom V Fold, Cheapest Fold...  2023-05-13T03:54:24Z
# ...                                                 ...                   ...
# 1403  [Jio, Unboxing & Review, Asus Zenfone Max, Zen...  2018-05-05T08:23:41Z
# 1404  [Engineering Counselling, tnea 2018, tnea appl...  2018-05-04T12:53:52Z
# 1405  [Home Automation, Unboxing, sensor light, sens...  2018-05-04T06:19:32Z
# 1406  [Unboxing & Review, FeiyuTech Vimble 2, Unboxi...  2018-05-02T06:20:42Z
# 1407  [Unboxing & Review, Zoom H1 Recorder, Digital ...  2018-04-26T02:31:09Z
#
#      viewCount likeCount favouriteCount commentCount duration definition  \
# 0       147277     32833           None          102    PT59S         hd
# 1       456594     47608           None          496    PT19S         hd
# 2       555502     74997           None          290    PT37S         hd
# 3       774937     91646           None          255    PT42S         hd
# 4       330657     15453           None          732  PT10M5S         hd
# ...        ...       ...            ...          ...      ...        ...
# 1403      9678       361           None           40  PT10M7S         hd
# 1404      3319       134           None           15  PT5M38S         hd
# 1405     49251       871           None           35  PT2M51S         hd
# 1406     21834       757           None           52  PT6M39S         hd
# 1407     44338      2737           None          263   PT6M8S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4       true
# ...      ...
# 1403   false
# 1404   false
# 1405   false
# 1406   false
# 1407   false
#
# [1408 rows x 13 columns]

# %%
 def vid_comments(youtube, vid_data):
    all_com = []
    for i in vid_data:
        try:
            val = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=i,
                maxResults=10
            )

            data = val.execute()
            if 'items' in data:
                all_comments = [j['snippet']['topLevelComment']['snippet']['textOriginal'] for j in data['items']]
            else:
                all_comments = None
            comments_data = {'video_id': i, 'comments': all_comments}
            all_com.append(comments_data)
        except HttpError as e:
            if e.resp.status in [403, 400]:
                comments_data = {'video_id': i, 'comments': None}
                all_com.append(comments_data)
            else:
                raise e
    return pd.DataFrame(all_com)
all_com = vid_comments(youtube, vid_data)
all_com
# Out:
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
#          video_id                                           comments
# 0     Ad-xWVaohVQ  [Semma akka neega 👌🤣🤭, Vera level bro😊, Adei c...
# 1     6zjB74XbDs8  [Anna neenga soniga la adhu na panni padhan an...
# 2     4XAw4yUMWYU  [x90 ku x80 pottu irukkiye bro😂😂🎉, when we for...
# 3     6rBtYBtrhwA  [😂😂😂😂, Full video podu nga, just now bought th...
# 4     M6qK-Q6pKdM  [Plsssss 😢whatspp database yepdi recovery panu...
# ...           ...                                                ...
# 1403  5jQsr0PfNCQ  [Currently I am using same Asus Zenfone max 1 ...
# 1404  HUYng0m8DC8  [Hi, Old tech boss to current tech boss awesom...
# 1405  ztLI7LGJbG8  [Intha video yanakku ippo recommend aaguthu 4 ...
# 1406  vBqO4gCIEKk  [3.m, வாழ்த்துக்கள்🎉🎊🎉🎊🎉🎊🎉🎊, Bro mobile la joy...
# 1407  HRxA_kAVBFM  [Waiting now for a new YouTube vlog idea.. 17t...
#
# [1408 rows x 2 columns]

# %%
vid_comments = pd.DataFrame(all_com)

# %%
vid_comments.head()
# Out:
#       video_id                                           comments
# 0  Ad-xWVaohVQ  [Semma akka neega 👌🤣🤭, Vera level bro😊, Adei c...
# 1  6zjB74XbDs8  [Anna neenga soniga la adhu na panni padhan an...
# 2  4XAw4yUMWYU  [x90 ku x80 pottu irukkiye bro😂😂🎉, when we for...
# 3  6rBtYBtrhwA  [😂😂😂😂, Full video podu nga, just now bought th...
# 4  M6qK-Q6pKdM  [Plsssss 😢whatspp database yepdi recovery panu...
